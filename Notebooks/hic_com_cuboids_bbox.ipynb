# %% [markdown]
# # Imports

# %%
import datagen
import numpy as np
from dghelpers import show_keypoints,imshow

# %% [markdown]
# # Center of Mass (COM)

# %%
dataset = datagen.load('../HIC Data', dataset_config = datagen.DatasetConfig(environment="hic"))
data_point = dataset[2]
imshow(data_point.visible_spectrum)
max_face = np.max(data_point.keypoints.face.standard.coords_3d[:2])
max_face
# Out:
# 1.9774326086044312
